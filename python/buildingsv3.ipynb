# %%
import osmium
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon

import pandas as pd
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %%
osm_file = "C:\\Users\\jerol\\Desktop\\JS\\foundation\\map.osm"

fp = osmium.FileProcessor(osm_file)\
         .with_areas()\
         .with_filter(osmium.filter.GeoInterfaceFilter())\
         .with_filter(osmium.filter.KeyFilter('building'))

features = gpd.GeoDataFrame.from_features(fp)
print(features)
# fig, ax = plt.subplots(1, 1, figsize=(40,40))
# features.plot(ax=ax)
# Out:
#                                                                                                                     geometry  \
# 0                                                                                                  POINT (103.68778 1.35373)
# 1                                                                                                  POINT (103.68849 1.35381)
# 2                                                                                                  POINT (103.68813 1.35375)
# 3    LINESTRING (103.68060 1.34506, 103.68056 1.34506, 103.68055 1.34560, 103.68056 1.34585, 103.68055 1.34600, 103.68056...
# 4    LINESTRING (103.68070 1.34371, 103.68086 1.34356, 103.68132 1.34309, 103.68149 1.34293, 103.68199 1.34246, 103.68215...
# ..                                                                                                                       ...
# 680  MULTIPOLYGON (((103.68302 1.34283, 103.68302 1.34261, 103.68304 1.34239, 103.68308 1.34215, 103.68312 1.34195, 103.6...
# 681         MULTIPOLYGON (((103.67653 1.34367, 103.67686 1.34366, 103.67686 1.34378, 103.67653 1.34378, 103.67653 1.34367)))
# 682         MULTIPOLYGON (((103.67613 1.34257, 103.67619 1.34254, 103.67626 1.34264, 103.67621 1.34267, 103.67613 1.34257)))
# 683         MULTIPOLYGON (((103.67617 1.34471, 103.67679 1.34471, 103.67679 1.34490, 103.67617 1.34490, 103.67617 1.34471)))
# 684         MULTIPOLYGON (((103.68666 1.34953, 103.68674 1.34937, 103.68692 1.34946, 103.68684 1.34962, 103.68666 1.34953)))
#
#      addr:city addr:postcode          addr:street    building  \
# 0    Singapore        636958  62 Nanyang Crescent         yes
# 1    Singapore        636960  66 Nanyang Crescent         yes
# 2    Singapore        636959  64 Nanyang Crescent         yes
# 3          NaN           NaN                  NaN  university
# 4          NaN           NaN                  NaN  university
# ..         ...           ...                  ...         ...
# 680  Singapore        639956       Nanyang Avenue  university
# 681        NaN           NaN                  NaN  industrial
# 682        NaN           NaN                  NaN        roof
# 683        NaN           NaN                  NaN  industrial
# 684        NaN           NaN                  NaN         yes
#
#                         name building:levels layer name:en name:ms  \
# 0     Binjai Hall (19A, 19B)             NaN   NaN     NaN     NaN
# 1     Banyan Hall (21A, 21B)             NaN   NaN     NaN     NaN
# 2    Tanjong Hall (20A, 20B)             NaN   NaN     NaN     NaN
# 3                North Spine               5     1     NaN     NaN
# 4                South Spine             NaN   NaN     NaN     NaN
# ..                       ...             ...   ...     ...     ...
# 680                     Gaia               6   NaN     NaN     NaN
# 681                      NaN             NaN   NaN     NaN     NaN
# 682                      NaN             NaN     1     NaN     NaN
# 683                      NaN             NaN   NaN     NaN     NaN
# 684                      NaN             NaN   NaN     NaN     NaN
#
#     addr:housenumber internet_access website fixme:zh name:zh addr:country  \
# 0                NaN             NaN     NaN      NaN     NaN          NaN
# 1                NaN             NaN     NaN      NaN     NaN          NaN
# 2                NaN             NaN     NaN      NaN     NaN          NaN
# 3                NaN             NaN     NaN      NaN     NaN          NaN
# 4                NaN             NaN     NaN      NaN     NaN          NaN
# ..               ...             ...     ...      ...     ...          ...
# 680               91             NaN     NaN      NaN     NaN          NaN
# 681              NaN             NaN     NaN      NaN     NaN          NaN
# 682              NaN             NaN     NaN      NaN     NaN          NaN
# 683              NaN             NaN     NaN      NaN     NaN          NaN
# 684              NaN             NaN     NaN      NaN     NaN          NaN
#
#     addr:housename                                                description  \
# 0              NaN                                                        NaN
# 1              NaN                                                        NaN
# 2              NaN                                                        NaN
# 3              NaN                                                        NaN
# 4              NaN                                                        NaN
# ..             ...                                                        ...
# 680            NaN  The largest Mass Engineered Timber (MET) building in Asia
# 681            NaN                                                        NaN
# 682            NaN                                                        NaN
# 683            NaN                                                        NaN
# 684            NaN                                                        NaN
#
#     name:zh-Hans name:zh-Hant operator phone source tourism amenity  \
# 0            NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 1            NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 2            NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 3            NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 4            NaN          NaN      NaN   NaN    NaN     NaN     NaN
# ..           ...          ...      ...   ...    ...     ...     ...
# 680          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 681          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 682          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 683          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 684          NaN          NaN      NaN   NaN    NaN     NaN     NaN
#
#     healthcare short_name opening_hours landuse man_made construction  \
# 0          NaN        NaN           NaN     NaN      NaN          NaN
# 1          NaN        NaN           NaN     NaN      NaN          NaN
# 2          NaN        NaN           NaN     NaN      NaN          NaN
# 3          NaN        NaN           NaN     NaN      NaN          NaN
# 4          NaN        NaN           NaN     NaN      NaN          NaN
# ..         ...        ...           ...     ...      ...          ...
# 680        NaN        NaN           NaN     NaN      NaN          NaN
# 681        NaN        NaN           NaN     NaN      NaN          NaN
# 682        NaN        NaN           NaN     NaN      NaN          NaN
# 683        NaN        NaN           NaN     NaN      NaN          NaN
# 684        NaN        NaN           NaN     NaN      NaN          NaN
#
#     addr:neighbourhood residential roof:material parking leisure sport  \
# 0                  NaN         NaN           NaN     NaN     NaN   NaN
# 1                  NaN         NaN           NaN     NaN     NaN   NaN
# 2                  NaN         NaN           NaN     NaN     NaN   NaN
# 3                  NaN         NaN           NaN     NaN     NaN   NaN
# 4                  NaN         NaN           NaN     NaN     NaN   NaN
# ..                 ...         ...           ...     ...     ...   ...
# 680                NaN         NaN           NaN     NaN     NaN   NaN
# 681                NaN         NaN           NaN     NaN     NaN   NaN
# 682                NaN         NaN           NaN     NaN     NaN   NaN
# 683                NaN         NaN           NaN     NaN     NaN   NaN
# 684                NaN         NaN           NaN     NaN     NaN   NaN
#
#     wikidata wikimedia_commons wikipedia fixme access bench shelter_type  bin  \
# 0        NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 1        NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 2        NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 3        NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 4        NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# ..       ...               ...       ...   ...    ...   ...          ...  ...
# 680      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 681      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 682      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 683      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 684      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
#
#                     alt_name  start_date
# 0                        NaN         NaN
# 1                        NaN         NaN
# 2                        NaN         NaN
# 3                        NaN         NaN
# 4                        NaN         NaN
# ..                       ...         ...
# 680  Academic Building South  2023-05-17
# 681                      NaN         NaN
# 682                      NaN         NaN
# 683                      NaN         NaN
# 684                      NaN         NaN
#
# [685 rows x 47 columns]

# %%
# polys = features.iloc[600:684]
# print(polys)
# fig, ax = plt.subplots(1, 1, figsize=(40,40))
# polys["geometry"].plot(ax=ax)
# plt.show()

# %%
filtered = features[features['geometry'].astype(str).str.startswith("MULTIPOLYGON")]
filtered = filtered[["name","geometry"]]
# print(filtered)
# fig, ax = plt.subplots(1, 1, figsize=(40,40))
# filtered.plot(ax=ax)
# plt.show()
# Out:
#                                                                                                                     geometry  \
# 343  MULTIPOLYGON (((103.68055 1.34600, 103.68056 1.34585, 103.68055 1.34560, 103.68056 1.34506, 103.68060 1.34506, 103.6...
# 344  MULTIPOLYGON (((103.68041 1.34409, 103.68074 1.34375, 103.68070 1.34371, 103.68086 1.34356, 103.68132 1.34309, 103.6...
# 345  MULTIPOLYGON (((103.68210 1.34319, 103.68225 1.34304, 103.68226 1.34305, 103.68231 1.34310, 103.68279 1.34359, 103.6...
# 346  MULTIPOLYGON (((103.68148 1.34380, 103.68160 1.34368, 103.68162 1.34366, 103.68167 1.34372, 103.68169 1.34373, 103.6...
# 347  MULTIPOLYGON (((103.68106 1.34212, 103.68152 1.34168, 103.68179 1.34153, 103.68222 1.34145, 103.68226 1.34183, 103.6...
# ..                                                                                                                       ...
# 680  MULTIPOLYGON (((103.68302 1.34283, 103.68302 1.34261, 103.68304 1.34239, 103.68308 1.34215, 103.68312 1.34195, 103.6...
# 681         MULTIPOLYGON (((103.67653 1.34367, 103.67686 1.34366, 103.67686 1.34378, 103.67653 1.34378, 103.67653 1.34367)))
# 682         MULTIPOLYGON (((103.67613 1.34257, 103.67619 1.34254, 103.67626 1.34264, 103.67621 1.34267, 103.67613 1.34257)))
# 683         MULTIPOLYGON (((103.67617 1.34471, 103.67679 1.34471, 103.67679 1.34490, 103.67617 1.34490, 103.67617 1.34471)))
# 684         MULTIPOLYGON (((103.68666 1.34953, 103.68674 1.34937, 103.68692 1.34946, 103.68684 1.34962, 103.68666 1.34953)))
#
#      addr:city addr:postcode     addr:street    building  \
# 343        NaN           NaN             NaN  university
# 344        NaN           NaN             NaN  university
# 345        NaN           NaN             NaN  university
# 346  Singapore        639798  Nanyang Avenue  university
# 347        NaN           NaN             NaN  university
# ..         ...           ...             ...         ...
# 680  Singapore        639956  Nanyang Avenue  university
# 681        NaN           NaN             NaN  industrial
# 682        NaN           NaN             NaN        roof
# 683        NaN           NaN             NaN  industrial
# 684        NaN           NaN             NaN         yes
#
#                                                    name building:levels layer  \
# 343                                         North Spine               5     1
# 344                                         South Spine             NaN   NaN
# 345                        Nanyang Business School (S3)             NaN     1
# 346  S. Rajaratnam School of International Studies (S4)             NaN     1
# 347        School of Physical and Mathematical Sciences             NaN   NaN
# ..                                                  ...             ...   ...
# 680                                                Gaia               6   NaN
# 681                                                 NaN             NaN   NaN
# 682                                                 NaN             NaN     1
# 683                                                 NaN             NaN   NaN
# 684                                                 NaN             NaN   NaN
#
#                                                 name:en  \
# 343                                                 NaN
# 344                                                 NaN
# 345                        Nanyang Business School (S3)
# 346  S. Rajaratnam School of International Studies (S4)
# 347        School of Physical and Mathematical Sciences
# ..                                                  ...
# 680                                                 NaN
# 681                                                 NaN
# 682                                                 NaN
# 683                                                 NaN
# 684                                                 NaN
#
#                                               name:ms addr:housenumber  \
# 343                                               NaN              NaN
# 344                                               NaN              NaN
# 345                   Sekolah Perniagaan Nanyang (S3)              NaN
# 346  Sekolah Pengajian Antarabangsa S Rajaratnam (S4)               50
# 347               Sekolah Sains Fizikal dan Matematik              NaN
# ..                                                ...              ...
# 680                                               NaN               91
# 681                                               NaN              NaN
# 682                                               NaN              NaN
# 683                                               NaN              NaN
# 684                                               NaN              NaN
#
#     internet_access                   website fixme:zh   name:zh addr:country  \
# 343             NaN                       NaN      NaN       NaN          NaN
# 344             NaN                       NaN      NaN       NaN          NaN
# 345             NaN                       NaN      NaN       NaN          NaN
# 346            wlan  https://www.rsis.edu.sg/      NaN       NaN          NaN
# 347             NaN                       NaN        -  物理与数学科学院          NaN
# ..              ...                       ...      ...       ...          ...
# 680             NaN                       NaN      NaN       NaN          NaN
# 681             NaN                       NaN      NaN       NaN          NaN
# 682             NaN                       NaN      NaN       NaN          NaN
# 683             NaN                       NaN      NaN       NaN          NaN
# 684             NaN                       NaN      NaN       NaN          NaN
#
#     addr:housename                                                description  \
# 343            NaN                                                        NaN
# 344            NaN                                                        NaN
# 345            NaN                                                        NaN
# 346            NaN                                                        NaN
# 347            NaN                                                        NaN
# ..             ...                                                        ...
# 680            NaN  The largest Mass Engineered Timber (MET) building in Asia
# 681            NaN                                                        NaN
# 682            NaN                                                        NaN
# 683            NaN                                                        NaN
# 684            NaN                                                        NaN
#
#     name:zh-Hans name:zh-Hant operator phone source tourism amenity  \
# 343          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 344          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 345          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 346          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 347          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# ..           ...          ...      ...   ...    ...     ...     ...
# 680          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 681          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 682          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 683          NaN          NaN      NaN   NaN    NaN     NaN     NaN
# 684          NaN          NaN      NaN   NaN    NaN     NaN     NaN
#
#     healthcare short_name opening_hours landuse man_made construction  \
# 343        NaN        NaN           NaN     NaN      NaN          NaN
# 344        NaN        NaN           NaN     NaN      NaN          NaN
# 345        NaN        NaN           NaN     NaN      NaN          NaN
# 346        NaN        NaN           NaN     NaN      NaN          NaN
# 347        NaN        NaN           NaN     NaN      NaN          NaN
# ..         ...        ...           ...     ...      ...          ...
# 680        NaN        NaN           NaN     NaN      NaN          NaN
# 681        NaN        NaN           NaN     NaN      NaN          NaN
# 682        NaN        NaN           NaN     NaN      NaN          NaN
# 683        NaN        NaN           NaN     NaN      NaN          NaN
# 684        NaN        NaN           NaN     NaN      NaN          NaN
#
#     addr:neighbourhood residential roof:material parking leisure sport  \
# 343                NaN         NaN           NaN     NaN     NaN   NaN
# 344                NaN         NaN           NaN     NaN     NaN   NaN
# 345                NaN         NaN           NaN     NaN     NaN   NaN
# 346                NaN         NaN           NaN     NaN     NaN   NaN
# 347                NaN         NaN           NaN     NaN     NaN   NaN
# ..                 ...         ...           ...     ...     ...   ...
# 680                NaN         NaN           NaN     NaN     NaN   NaN
# 681                NaN         NaN           NaN     NaN     NaN   NaN
# 682                NaN         NaN           NaN     NaN     NaN   NaN
# 683                NaN         NaN           NaN     NaN     NaN   NaN
# 684                NaN         NaN           NaN     NaN     NaN   NaN
#
#     wikidata wikimedia_commons wikipedia fixme access bench shelter_type  bin  \
# 343      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 344      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 345      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 346      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 347      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# ..       ...               ...       ...   ...    ...   ...          ...  ...
# 680      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 681      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 682      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 683      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
# 684      NaN               NaN       NaN   NaN    NaN   NaN          NaN  NaN
#
#                     alt_name  start_date
# 343                      NaN         NaN
# 344                      NaN         NaN
# 345                      NaN         NaN
# 346                      NaN         NaN
# 347                      NaN         NaN
# ..                       ...         ...
# 680  Academic Building South  2023-05-17
# 681                      NaN         NaN
# 682                      NaN         NaN
# 683                      NaN         NaN
# 684                      NaN         NaN
#
# [342 rows x 47 columns]

# %%
# filtered = filtered[filtered['geometry']]

# %%
# pd.options.display.max_colwidth = 120
# print(filtered)

# %%
filtered.to_file('output_file.json')

# %%
new_df = pd.DataFrame({
    'name': features['properties.name'],
    'coordinates': features['geometry'].apply(lambda geom: geom.coords[0] if geom else None)
})
# df = pd.json_normalize(features)
print(new_df)
# filtered = df[df['geometry.type'] == "MULTIPOLYGON"]
# filtered = filtered[['properties.name','geometry.coordinates']]

# print(filtered)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'properties.name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 new_df = pd.DataFrame({
# ----> 2     'name': features['properties.name'],
#       3     'coordinates': features['geometry'].apply(lambda geom: geom.coords[0] if geom else None)
#       4 })
#       5 # df = pd.json_normalize(features)
#       6 print(new_df)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\geopandas\geodataframe.py:1459, in GeoDataFrame.__getitem__(self, key)
#    1453 def __getitem__(self, key):
#    1454     """
#    1455     If the result is a column containing only 'geometry', return a
#    1456     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1457     return a GeoDataFrame.
#    1458     """
# -> 1459     result = super().__getitem__(key)
#    1460     # Custom logic to avoid waiting for pandas GH51895
#    1461     # result is not geometry dtype for multi-indexes
#    1462     if (
#    1463         pd.api.types.is_scalar(key)
#    1464         and key == ""
#    (...)
#    1467         and not is_geometry_type(result)
#    1468     ):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'properties.name'

# %%
import folium

min_lat,min_lon = 1.3399,103.6764
max_lat,max_lon = 1.3562,103.6904
# gdf_wgs84 = features.to_crs(epsg=4326)
m = folium.Map(location=[filtered.geometry.centroid.y.mean(), filtered.geometry.centroid.x.mean()], 
               zoom_start=20,
                max_bounds=True,
                min_lat=min_lat,
                max_lat=max_lat,
                min_lon=min_lon,
                max_lon=max_lon,
            )
for _, row in features.iterrows():
    folium.GeoJson(row['geometry']).add_to(m)
print(m)
# m.save('interactive_map_3.html')
# Out:
# <folium.folium.Map object at 0x000001A69C4FC920>

# %%
from folium import IFrame

min_lat,min_lon = 1.3399,103.6764
max_lat,max_lon = 1.3562,103.6904
# gdf_wgs84 = features.to_crs(epsg=4326)
m = folium.Map(location=[filtered.geometry.centroid.y.mean(), filtered.geometry.centroid.x.mean()], 
               zoom_start=20,
                max_bounds=True,
                min_lat=min_lat,
                max_lat=max_lat,
                min_lon=min_lon,
                max_lon=max_lon,
            )

# JavaScript for handling click events and changing polygon styles
js_code = '''
function onEachFeature(feature, layer) {
    layer.on('click', function (e) {
        if (layer.options.color === 'blue') {
            layer.setStyle({
                color: 'red'  // Change line color to red on click
            });
            feature.properties.clicked = true;  // Mark the feature as clicked
        } else {
            layer.setStyle({
                color: 'blue'  // Reset line color to blue if clicked again
            });
            feature.properties.clicked = false;  // Reset clicked state
        }
    });
}
'''

# Convert GeoDataFrame to GeoJSON format
geojson_data = filtered["geometry"].to_json()
# print(geojson_data)

for _, row in features.iterrows():
    folium.GeoJson(
        row['geometry'],  # Each individual geometry
        # Add the JavaScript function to handle click events
        on_each_feature=js_code  # Injecting the JavaScript click handling code
    ).add_to(m)

# Save the map with interactive click handling
m.save('interactive_map_4.html')
